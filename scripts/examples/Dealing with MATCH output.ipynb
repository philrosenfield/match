# %%
from IPython.core.display import Image

# %% [markdown]
# # Looking at the SFH solution

# %%
! python -m match.scripts.sfh -h
# Out:
# usage: sfh.py [-h] [--oneplot] [sfh_files [sfh_files ...]]
#
# Plot match sfh
#
# positional arguments:
#   sfh_files   ssp output(s) or formated output(s)
#
# optional arguments:
#   -h, --help  show this help message and exit
#   --oneplot   overlay on one plot

# %%
! python -m match.scripts.sfh ugc4305-1/ugc4305-1_f555w_f814w.mcmc.zc
# Out:
# wrote ugc4305-1/ugc4305-1_f555w_f814w.mcmc.zc.png
# wrote ugc4305-1/ugc4305-1_f555w_f814w.mcmc.zc_csfr.png

# %%
# SFR and M/H vs Age (if there are uncertainties, will plot them too)
Image('ugc4305-1/ugc4305-1_f555w_f814w.mcmc.zc.png')

# %%
# Cumulative SFR (if there are uncertainties, will plot them too)
Image('ugc4305-1/ugc4305-1_f555w_f814w.mcmc.zc_csfr.png')

# %% [markdown]
# # Looking at the ouput CMD files

# %%
! python -m match.scripts.cmd -h
# Out:
# usage: cmd.py [-h] [-o OUTDIR] [-f] [-c] [-s] [--logcounts] [--nmax NMAX]
#               [cmdfiles [cmdfiles ...]]
#
# plot cmd file
#
# positional arguments:
#   cmdfiles              .cmd files to plot
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -o OUTDIR, --outdir OUTDIR
#                         directory to place images
#   -f, --byfit           number filenames by best fit
#   -c, --stats           call match/bin/stats and exit
#   -s, --split           split cmd file if it contains more than one CMD
#   --logcounts           use log binning for data and model
#   --nmax NMAX           max best cmds to plot with --byfit

# %%
# Can be one or many .cmd files
! python -m match.scripts.cmd ugc4305-1/ugc4305-1_f555w_f814w.out.cmd
# Out:
# ugc4305-1/ugc4305-1_f555w_f814w.out.cmd
# wrote /Users/rosenfield/Library/Mobile Documents/com~apple~CloudDocs/Work/match/scripts/examples/ugc4305-1/ugc4305-1_f555w_f814w.out.cmd.png

# %%
# A pgcmd-like output
Image('ugc4305-1/ugc4305-1_f555w_f814w.out.cmd.png')
