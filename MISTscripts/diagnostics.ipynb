# %%
import diagnostics as dg
import os

# %%
dg.readssp()
# Out:
# Reading jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.0_cov0.016.ssp
# !
# (array([9211]), array([ 8.97755]), array([ 0.00047458]))

# %%
dg.plotouts([8.98,9.00], SFRS=['0.01','0.001','0.0001','0.00001','0.000007','0.000006','0.000005', '0.000003','0.000002','0.000001'], solution='subsampled', save_path=os.getcwd())
# Out:
# 0.01
# Reading jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.0_cov0.016.ssp
# Getting subsampled marginalized solution...
# !
# [ 8.98]
# (8.9775066630000016, 8.9824933369999993)
# Plotted 1 points.
# SFR = 0.01 (92973 stars)
# scatter (std.dev. of best fits): 0.000000
# mean uncert: 0.002267
# scatter / mean uncert: 0.000000
# ...
# 0.001
# Reading jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.0_cov0.016.ssp
# Getting subsampled marginalized solution...
# !
# [ 8.98]
# (8.9775066630000016, 9.0720893366999995)
# Plotted 1 points.
# SFR = 0.001 (9211 stars)
# scatter (std.dev. of best fits): 0.000000
# mean uncert: 0.002267
# scatter / mean uncert: 0.000000
# ...
# 0.0001
# Reading jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.0_cov0.016.ssp
# Getting subsampled marginalized solution...
# !
# [ 8.98]
# (8.8879559967000006, 9.0720893366999995)
# Plotted 1 points.
# SFR = 0.0001 (898 stars)
# scatter (std.dev. of best fits): 0.000000
# mean uncert: 0.002267
# scatter / mean uncert: 0.000000
# ...
# 0.00001
# ...
