# %%
import diagnostics as dg
import os
# Out:
# /home/seth/Programs/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
dg.readssp()
# Out:
# ['jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.0_cov0.016.ssp']
# jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.0_cov0.016.ssp
# Reading jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.0_cov0.016.ssp
# *
# []
# **
# (array([9211]), array([ 8.97755]), array([ 0.00047458]))

# %%
#'0.1', #'0.000001', 
#'0.1','0.01','0.001','0.0001','0.00001',
#                  '0.000007','0.000006','0.000005', 
#                  '0.000003','0.000002', '0.000001'

dg.plotouts(params=['lage','logZ','vvcrit'], vvcs=['0.4'],
            SFRS=['0.0001'], solution='subsampled', 
            save_path="/home/seth/Documents/tex/ClusterPaper/graphics/bestfit_age_vs_N.eps", debug=False, marg=True)
# Out:
# 0.0001
# Reading /home/seth/Research/MATCH/match2.7/MIST/Fakedata/scrns/SFR0.0001_logZ0.05_dmag0.10_dcol0.05_vvc0.4/SLURM12345678/jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.4_cov0.016.scrn...
# Reading /home/seth/Research/MATCH/match2.7/MIST/Fakedata/scrns/SFR0.0001_logZ0.05_dmag0.10_dcol0.05_vvc0.4/SLURM12345678/jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.5_cov0.016.scrn...
# Reading /home/seth/Research/MATCH/match2.7/MIST/Fakedata/scrns/SFR0.0001_logZ0.05_dmag0.10_dcol0.05_vvc0.4/SLURM12345678/jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.1_cov0.016.scrn...
# Reading /home/seth/Research/MATCH/match2.7/MIST/Fakedata/scrns/SFR0.0001_logZ0.05_dmag0.10_dcol0.05_vvc0.4/SLURM12345678/jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.3_cov0.016.scrn...
# Reading /home/seth/Research/MATCH/match2.7/MIST/Fakedata/scrns/SFR0.0001_logZ0.05_dmag0.10_dcol0.05_vvc0.4/SLURM12345678/jobid87654321_imf1.35_bf0.0_dav0.10_vvcrit0.2_cov0.016.scrn...
# ...
